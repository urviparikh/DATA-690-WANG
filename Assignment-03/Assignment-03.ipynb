# %% [markdown]
# # Assignment 03

# %% [markdown]
# ### 10x10 Matrix

# %%
import random # in order to generate random numbers

def random_matrix(row_num=10):
    my_matrix = []

    for my_rows in range(row_num):
        my_rows = []

        for my_elements in range(row_num):
            my_elements = random.randint(0,9)
            
            print(my_elements, end= " ")

            my_rows.append(my_elements)

        print("")
        my_matrix.append(my_rows)

random_matrix(10)
# Out:
# 3 8 8 3 7 7 5 6 3 1
# 0 7 9 8 5 6 6 9 3 0
# 1 8 9 3 4 2 5 8 5 0
# 0 3 2 7 2 5 9 9 6 9
# 0 5 9 9 6 6 1 5 3 5
# 0 5 9 9 2 8 2 3 0 5
# 1 8 4 6 0 0 4 4 9 2
# 3 9 1 5 2 9 4 0 4 6
# 7 1 2 2 5 3 8 5 2 8
# 5 9 0 6 0 1 8 8 6 3

# %% [markdown]
# ### Printing '@' in place of odd numbers

# %%
import random

def random_matrix(row_num=10):
    my_matrix = []

    for my_rows in range(row_num):
        my_rows = []

        for my_elements in range(row_num):
            my_element = random.randint(0,9)
            if (my_elements % 2 ==1): # determines if the integer is divisible by 2 to identify odd numbers 
              print('@', end=" ")
            else:
              print(my_elements, end= " ")


            my_rows.append(my_elements)

        print("")
        my_matrix.append(my_rows)

random_matrix(10)
# Out:
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @
# 0 @ 2 @ 4 @ 6 @ 8 @

# %% [markdown]
# ### Total of each row displayed next to the matrix

# %%
import random

def random_matrix(row_num=10, matrix_return='on'):
    my_matrix = []

    for matrix_rows in range(row_num):
        my_rows = [] # creating an empty array 
        row_total = 0

        for my_elements in range(row_num):
            my_elements = random.randint(0,9)
            
            if (my_elements % 2 ==1):
                a = '@'

              #print('@', end=" ")
            #else:
              #print(my_element, end= " ")  
              # this prints '@' in place of odd numbers noted previously

            my_rows.append(my_elements)


            try:
                row_total= row_total + my_elements
            except:
                row_total = row_total + 0
            print(my_elements, end=" ")


        my_rows.append(f"* {row_total}")
        print(f"* {row_total}")
        my_matrix.append(my_rows)

    if matrix_rows == 'on':
        return(my_matrix)


random_matrix(10)
# Out:
# 0 0 5 1 4 0 3 3 7 5 * 28
# 8 2 9 7 5 9 4 9 6 3 * 62
# 9 4 2 1 7 3 7 6 5 6 * 50
# 7 8 1 6 8 7 4 5 0 1 * 47
# 4 1 6 1 3 1 3 8 9 3 * 39
# 0 8 7 5 0 3 8 5 4 1 * 41
# 5 7 4 1 3 8 4 9 0 2 * 43
# 6 9 2 9 8 1 0 0 2 9 * 46
# 6 6 9 1 5 0 2 1 3 0 * 33
# 2 8 4 0 2 4 3 0 9 0 * 32

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1ec7e970-07da-4e5c-80d8-e5f7aecc40a2' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
