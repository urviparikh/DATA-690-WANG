# %%
# 
print("Hello World");
# Out:
# Hello World

# %%
print("Practice starts here")
# Out:
# Practice starts here

# %%
x=5
y=7
print(x*y)
# Out:
# 35

# %%
import numpy as np

# %%
import numpy as np
In [6]: data = {i : np.random.randn() for i in range(7)}
In [7]: data
# Out:
# {0: -0.20425567221918026,
#  1: 0.7628566596744957,
#  2: 0.0706035599541185,
#  3: 0.4887602023060696,
#  4: -1.3814126985270208,
#  5: 0.7040106960577378,
#  6: -1.3008719221978786}

# %%
In [8]: b = [1, 2, 3]
In [9]: b?

# %%
# %pwd
# Out:
# '/work'

# %%
for x in array: # which works once array is defined 
    if x < pivot:
        less.append(x)
    else:
        greater.append(x)

# %%
a=[1,2,3]
b=a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
a=5
type(a)
# Out:
# int

# %%
a='star'
type(a)
a=5
isinstance(a,int)
# Out:
# True

# %%
a='stat'
getattr(a,'split')
# Out:
# <function str.split(sep=None, maxsplit=-1)>

# %%
def isiterable(obj):
    try:
        iter(obj)
        return True
    except TypeError: # not iterable
        return False

# %%
isiterable('a string')
isiterable([1,2,3])
# Out:
# True

# %%
from datetime import datetime, date, time
dt = datetime(2011, 10, 29, 20, 30, 21)
dt.date()
dt.strftime('%m/%d/%Y %H:%M')
# Out:
# '10/29/2011 20:30'

# %%
if x < 0:
    print('It's negative')
elif x == 0:
    print('Equal to zero')
elif 0 < x < 5:
    print('Positive but smaller than 5')
else:
    print('Positive and larger than or equal to 5')

# %%
sequence = [1, 2, None, 4, None, 5]
total = 0
for value in sequence:
    if value is None:
        continue
    total += value

# %%
x = 256
total = 0
while x > 0:
    if total > 500:
        break
    total += x
    x = x // 2

# %%
sum = 0
for i in range(100000):
    # % is the modulo operator
    if i % 3 == 0 or i % 5 == 0:
        sum += i
